# %%
import pandas as pd
people_dict = { "weight": pd.Series([68, 83, 112],index=["alice", "bob", "charles"]),   "birthyear": pd.Series([1984, 1985, 1992], index=["bob", "alice", "charles"], name="year"),
"children": pd.Series([0, 3], index=["charles", "bob"]),
"hobby": pd.Series(["Biking", "Dancing"], index=["alice", "bob"]),}

# %%
people_df = pd.DataFrame(people_dict)
>>> people_df
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %%
 people[people["birthyear"] < 1990]
# Out:
#        weight  birthyear  children    hobby
# alice      68       1985       NaN   Biking
# bob        83       1984       3.0  Dancing

# %%
people_df.describe()
# Out:
#            weight    birthyear  children
# count    3.000000     3.000000   2.00000
# mean    87.666667  1987.000000   1.50000
# std     22.368132     4.358899   2.12132
# min     68.000000  1984.000000   0.00000
# 25%     75.500000  1984.500000   0.75000
# 50%     83.000000  1985.000000   1.50000
# 75%     97.500000  1988.500000   2.25000
# max    112.000000  1992.000000   3.00000

# %%
iris_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
import pandas as pd
iris_data= pd.read_csv(iris_url)
iris_data
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
iris_df= pd.read_csv(iris_url, names=['sepal length','sepal width','petal length','petal width','target'])
iris_df
# Out:
#      sepal length  sepal width  petal length  petal width          target
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_df.head()
# Out:
#    sepal length  sepal width  petal length  petal width       target
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_df.iloc[:,3].hist()

# %%
features = ['sepal length', 'sepal width', 'petal length', 'petal width']
iris_df[features].hist(figsize=(10, 4));

# %%
iris_df[features].plot(kind='density', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8f8037ebe0>,
# ...
#       dtype=object)

# %%
import seaborn as sns
sns.distplot(iris_df['sepal width']);

# %%
sns.distplot(iris_df['sepal length']);

# %%
sns.distplot(iris_df['petal width']);

# %%
sns.distplot(iris_df['petal length']);

# %%
import seaborn as sns
# Calculate and plot
corr_matrix = iris_df.corr()
sns.heatmap(corr_matrix);

# %%
import matplotlib.pyplot as plt
plt.scatter(iris_df.iloc[:,0], iris_df.iloc[:,2]);

# %%
import matplotlib.pyplot as plt
plt.scatter(iris_df.iloc[:,0], iris_df.iloc[:,2],alpha=0.2,
           cmap='viridis');

# %%
iris_df.iloc[:,0]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length, Length: 150, dtype: float64

# %%
plt.scatter(iris_df.iloc[:,1], iris_df.iloc[:,3]);

# %%
import matplotlib.pyplot as plt
plt.scatter(iris_df.iloc[:,1], iris_df.iloc[:,3],alpha=0.2,
           cmap='viridis');

# %%
sns.jointplot(iris_df.iloc[:,1], iris_df.iloc[:,3], 
              data=iris_df, kind='scatter');

# %%
sns.jointplot(iris_df.iloc[:,0], iris_df.iloc[:,2], data=iris_df,
              kind="kde", color="g");

# %%
# %config InlineBackend.figure_format = 'png'
sns.pairplot(iris_df);
